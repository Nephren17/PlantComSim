# %%
import numpy as np

def simulate_weather():
    # 一年内每个月的天数
    days_in_month = [31,28,31,30,31,30,31,31,30,31,30,31]

    # 平均气温
    temp = []
    for i in range(12):
        # 亚热带稀树草原的平均温度为18-22摄氏度
        temp_month = np.random.normal(loc=20, scale=2)
        if i in [0,1,11]: # 冬季
            temp_month = np.random.normal(loc=10, scale=2)
        elif i in [6,7,8]: # 夏季
            temp_month = np.random.normal(loc=26, scale=2)
        temp.append(temp_month)
    
    # 湿度
    humidity = []
    for i in range(12):
        # 亚热带稀树草原的平均湿度为50-70%
        humidity_month = np.random.normal(loc=60, scale=5)
        if i in [5,6,7]: # 雨季
            humidity_month = np.random.normal(loc=80, scale=5)
        elif i in [1,2,11]: # 旱季
            humidity_month = np.random.normal(loc=40, scale=5)
        humidity.append(humidity_month)

    # 降水量
    precipitation = []
    for i in range(12):
        # 亚热带稀树草原的平均降水量为600-900毫米
        precipitation_month = np.random.normal(loc=750, scale=50)
        if i in [5,6,7]: # 雨季
            precipitation_month = np.random.normal(loc=1000, scale=100)
        elif i in [1,2,11]: # 旱季
            precipitation_month = np.random.normal(loc=400, scale=50)
        precipitation.append(precipitation_month)

    # 光照
    sunshine = []
    for i in range(12):
        # 亚热带稀树草原的平均日照时数为2200-2600小时
        sunshine_month = np.random.normal(loc=2400, scale=200)
        if i in [0,1,11]: # 冬季
            sunshine_month = np.random.normal(loc=2000, scale=200)
        elif i in [6,7,8]: # 夏季
            sunshine_month = np.random.normal(loc=2800, scale=200)
        sunshine.append(sunshine_month)

    return temp, humidity, precipitation, sunshine

# %%
climate_simulator()
# Out:
# (array([28.        , 27.33012702, 25.5       , 23.        , 20.5       ,
#         18.66987298, 18.        , 18.66987298, 20.5       , 23.        ,
#         25.5       , 27.33012702]),
#  array([  0.        ,   0.        ,   1.66274922, 124.05938635,
#          93.00637857, 145.24795954,  64.46979574,  38.4785245 ,
#         156.84724038, 151.70624468,  61.73954762,  60.9757992 ]),
#  array([137.76495144, 154.64368304, 147.92602847, 153.83088412,
#         154.94093071, 186.14893761, 142.60781108, 156.97512977,
#         160.8151178 , 162.36394177, 151.39684374, 138.4406916 ]),
#  array([250.96872007, 267.36158336, 246.35702183, 230.39200022,
#         271.28988376, 241.84393505, 261.14739346, 244.89979496,
#         256.68094936, 246.29285818, 263.16136505, 236.94777502]))

# %%
import matplotlib.pyplot as plt

def plot_climate_simulator(year_temp, year_humidity, year_rainfall, year_sunlight):
    fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
    months = range(1, 13)

    # Plot temperature
    axs[0, 0].plot(months, year_temp, marker='o')
    axs[0, 0].set_title('Average Monthly Temperature (Celsius)')
    axs[0, 0].set_xlabel('Month')
    axs[0, 0].set_xticks(months)

    # Plot humidity
    axs[0, 1].plot(months, year_humidity, marker='o')
    axs[0, 1].set_title('Average Monthly Humidity (%)')
    axs[0, 1].set_xlabel('Month')
    axs[0, 1].set_xticks(months)

    # Plot rainfall
    axs[1, 0].plot(months, year_rainfall, marker='o')
    axs[1, 0].set_title('Average Monthly Rainfall (mm)')
    axs[1, 0].set_xlabel('Month')
    axs[1, 0].set_xticks(months)

    # Plot sunlight
    axs[1, 1].plot(months, year_sunlight, marker='o')
    axs[1, 1].set_title('Average Monthly Sunlight (hours)')
    axs[1, 1].set_xlabel('Month')
    axs[1, 1].set_xticks(months)

    # Adjust spacing and show plot
    fig.tight_layout()
    plt.show()

# %%
year_temp, year_humidity, year_rainfall, year_sunlight = climate_simulator()

plot_climate_simulator(year_temp, year_humidity, year_rainfall, year_sunlight)
